# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML, IFrame, Video
import ipywidgets as widgets
from ipywidgets import interact, fixed, Dropdown, Checkbox, FloatSlider, IntSlider, Output, VBox, HBox

from numpy import cos, sin, tan, arctan, exp, log, pi, array, linspace, arange, sqrt
from numpy.linalg import norm
from mpl_toolkits import mplot3d

# %matplotlib widget

# Uncomment the one that corresponds to your Jupyter theme
plt.style.use('default')
# plt.style.use('dark_background')
# plt.style.use('fivethirtyeight')
# plt.style.use('Solarize_Light2')

plt.rcParams.update({
    "figure.figsize": (6,6),
    "text.usetex": True,
    "font.family": "serif",
})

# %% [markdown]
# $\newcommand{\RR}{\mathbb{R}}$
# $\newcommand{\bv}[1]{\begin{bmatrix} #1 \end{bmatrix}}$
# $\renewcommand{\vec}{\mathbf}$

# %%
# %%html
#
# <style>
# .shadow {
#
#     /*Edit or add new attributes, change size, color, etc */
#     width: 75%;
#     box-shadow: 8px 8px 10px #444;
#     border: 1px solid silver;
#
#     /*For positioning in a jupyter notebook*/
#     margin-top: 2em;
#     position: relative;
#     top: -25px
# }
#
# ol li {
#     padding: .5em;
# }
# </style>
# Out:
# <style>
# .shadow {
#
#     /*Edit or add new attributes, change size, color, etc */
#     width: 75%;
#     box-shadow: 8px 8px 10px #444;
#     border: 1px solid silver;
#
#     /*For positioning in a jupyter notebook*/
#     margin-top: 2em;
#     position: relative;
#     top: -25px
# }
#
# ol li {
#     padding: .5em;
# }
# </style>

# %% [markdown]
# <p style="padding-bottom:40%;"> </p>

# %% [markdown]
# ## One-minute Review
#
# The **linearization** of a differentiable function $f(x,y)$ about a point $(a,b)$ is the linear function
# $$f(x, y) \approx L(x,y) = f(a,b) + f_x(a,b)(x-a)  + f_y(a,b)(y-b). $$
#
# Its graph is tangent to the graph of $f$.

# %% [markdown]
# <p style="padding-bottom:40%;"> </p>

# %% [markdown]
# # Lecture 10 - The Chain Rule
#
# <img style="float: right" width="30%" src="../img/PatchedCabinets.jpeg">
#
#   - Objectives
#     - Compute derivatives of compositions.
#     - Compute derivatives from implicit relations.
#
#   - Resources
#     - Content
#       - Stewart: §14.5
#       - New Strang: [§4.5](https://cnx.org/contents/oxzXkyFi@6.1:8QoqMp7K@7/4-5-The-Chain-Rule)
#
#     - Practice
#       - Mooculus: [Chain Rule](https://ximera.osu.edu/mooculus/calculus3/directionalDerivativeAndChainRule/digInChainRule)
#     - Extras
#       - CalcBLUE: WARNING! This is very matrix-dependent (and thus extra) [The Chain Rule](https://youtu.be/3WtjD3bewBk)
#
# [Photo credit: Joe Paradiso](http://paradiso.media.mit.edu/synth.html)

# %% [markdown]
# <p style="padding-bottom:40%;"> </p>

# %% [markdown]
# <div class="alert alert-block alert-info shadow">
# <strong>Theorem of Differentiability</strong>
# <p>If all partial derivatives $\frac{\partial f}{\partial x_i}$ are continuous in a neighborhood of a point $P$, then $f$ is differentiable at $P$. </p>
# </div>

# %% [markdown]
# #### Nonexample
#
# Consider $$f(x,y) = \frac{xy}{\sqrt{x^2 + y^2}}.$$

# %%
def a(TITLE):
    if TITLE in plt.get_figlabels():
        plt.close(plt.figure(TITLE))
    
    plt.ioff()
    fig = plt.figure(num=TITLE)
    ax = fig.add_subplot(projection="3d")
    plt.ion()
    
    x = y = np.linspace(-1,1,100)
    x,y = np.meshgrid(x,y)
    ax = fig.add_subplot(projection='3d')

    ax.plot_surface(x,y,x*y/(sqrt(x**2 + y**2)),cmap='viridis',alpha=.5)
    # ax.contour(x,y,x*y/(sqrt(x**2 + y**2)))
    ax.contour(x,y,x*y/(sqrt(x**2 + y**2)),zdir='x',cmap='gray_r')
    ax.contour(x,y,x*y/(sqrt(x**2 + y**2)),zdir='y',cmap='gray');
    
    return fig.canvas

a("A Non-differentiable function")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# [Demo](https://3demos.surge.sh/?currentChapter=Intro&shadeUp=true&flipInfo=true&grid=false&obj0_kind=graph&obj0_params_a=-2&obj0_params_b=2.001&obj0_params_c=-2&obj0_params_d=2&obj0_params_z=x+y+%2F+sqrt%28x%5E2+%2B+y%5E2%29&obj0_params_tau=0&obj0_params_t0=0&obj0_params_t1=1&obj0_params_color=%233232ff)
#
# \begin{align*}
# f_{x} &= \frac{y}{\sqrt{x^2 + y^2}} - \frac{x^2y}{(x^2 +y^2)^{3/2}} \\
# \end{align*}
#
# are not continuous near the origin.

# %% [markdown]
# <p style="padding-bottom:40%;"> </p>

# %% [markdown]
# <p style="padding-bottom:40%;"> </p>

# %% [markdown]
# <div class="alert alert-block alert-info shadow">
#     <strong>The Chain Rule (1-D)</strong>
#
# <p>Start by recalling the 1-D chain rule $$(f\circ g)'(x) = f'(g(x))g'(x)$$ or, letting $u=g(x)$,
# $$ \frac{df}{dx} = \frac{df}{du}\frac{du}{dx}$$ where the derivatives are evaluated at the appropriate point.</p>
# </div>

# %%
Video("../img/chain_rule_1d.mp4", html_attributes="loop autoplay")
# Out:
# <video src="../img/chain_rule_1d.mp4" loop autoplay  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# <p style="padding-bottom:40%;"> </p>

# %% [markdown]
# ## The main problem
#
# Suppose a hiking party charts a route on a map given by $\langle x(t),y(t) \rangle$ where the altitude is given by a function $f(x,y)$.
#
# What is $\frac{df}{dt}$ at a given time $t_0$?

# %%
def a(TITLE):
    if TITLE in plt.get_figlabels():
        plt.close(plt.figure(TITLE))
    
    plt.ioff()
    fig = plt.figure(num=TITLE, figsize=(10,5))
    plt.ion()
    ax = fig.add_subplot(121, projection='3d') 
    
    # make axes lines
    ax.plot([-1,1],[0,0],[0,0],'gray')
    ax.plot([0,0],[-1,1],[0,0],'gray')
    ax.plot([0,0],[0,0],[-1,1],'gray')   

    for c in 'xyz':
        getattr(ax,f"set_{c}lim")([-1,1]);    
        getattr(ax,f"set_{c}label")(f"${c}$",size=16)
    
    ax.set_autoscale_on(True)

    func = lambda x,y: exp(-4*(y-sin(x))**2)*(1-np.abs(x+pi/2)/5)
    
    x =  np.linspace(-4,4,601)
    y =  np.linspace(-2,2,301)    
    X,Y = np.meshgrid(x,y)
    Z = func(X,Y)
    ax.plot_surface(X,Y,Z,alpha=.6,cmap='ocean',rcount=100,ccount=100);
    t = np.linspace(-pi/2,pi/2,100)
    X = t
    Y = t/pi - 1/2 - t*(t**2-pi**2/4)/5
    Z = func(X,Y)
    ax.plot(X,Y,Z,lw=6,color='r',alpha=1)
    


    ax2 = fig.add_subplot(122)
    ax2.plot((pi/2-t)/pi*4,Z)
    ax2.set_xlabel("$t$",size=16)
    ax2.set_ylabel("$z$",size=16)
    ax.set_zlim3d([0,1])
    ax2.set_ylim([0,1])    
    
    pl = ax.plot([], [], [], lw=4)[0]
    pl2 = ax2.plot([],[])[0]
    
    slider = widgets.IntSlider(min=1, max = 98, value=98)
    
    def update(change):
        pt = 99 - slider.value
        dt = t[pt+1]-t[pt-1]
        dx = X[pt+1]-X[pt-1]
        dy = Y[pt+1]-Y[pt-1]
        dz = Z[pt+1]-Z[pt-1]
        s = np.linspace(-20,20,100)
        pl.set_data_3d(X[pt] + dx*s,Y[pt] + dy*s,Z[pt] + dz*s)
        pl2.set_data((pi/2-t)/pi*4,dz/dt*(t-t[pt])+Z[pt])

    slider.observe(update, names='value')
    
    update({'new': 97})
    
    return widgets.VBox([slider, fig.canvas])

a("Hiking up a mountain")
# Out:
# VBox(children=(IntSlider(value=98, max=98, min=1), Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original …

# %% [markdown]
# ##### Clue: replace $f$ with $L$

# %% [markdown]
# [Tangents demo](https://3demos.surge.sh/?currentChapter=Intro&shadeUp=true&flipInfo=true&obj0_kind=graph&obj0_params_a=-2&obj0_params_b=2&obj0_params_c=-2&obj0_params_d=2&obj0_params_z=1-%28x+-+1%29%5E2%2F6+-+%28y+%2B+1%29%5E2+%2F+10&obj0_params_tau=0&obj0_params_t0=0&obj0_params_t1=1&obj1_kind=curve&obj1_params_a=0&obj1_params_b=2*pi&obj1_params_x=cos%28t%29&obj1_params_y=sin%28t%29&obj1_params_z=1-%28cos%28t%29+-+1%29%5E2%2F6+-+%28sin%28t%29+%2B+1%29%5E2+%2F+10&obj1_params_tau=0&obj2_kind=curve&obj2_params_a=-pi%2F6&obj2_params_b=pi%2F6&obj2_params_x=cos%28t%29&obj2_params_y=sin%28t%29&obj2_params_z=9%2F10+-+%28sin%28t%29%29%2F5&obj2_params_tau=0)

# %%
def a(TITLE):
    if TITLE in plt.get_figlabels():
        plt.close(plt.figure(TITLE))

    plt.ioff()
    fig = plt.figure(num=TITLE)
    plt.ion()

    ax = fig.add_subplot(111,projection='3d')
    x = y = np.linspace(0,2,75)
    x,y = np.meshgrid(x,y)

    for c in 'xyz':
    #         getattr(ax,f"set_{c}lim")([-1,1]);    
        getattr(ax,f"set_{c}label")(f"${c}$",size=16)
    ax.plot_surface(x,y,-(x-2)**2 - (y-2)**2/2,alpha=.5)
    ax.plot_surface(x,y,2*(x-1) + (y-1) -3/2,alpha=.5)
    t = np.linspace(0,2,50)
    ax.plot(t,t,-(t-2)**2 - (t-2)**2/2)
    ax.plot(t,t,2*(t-1) + (t-1) - 3/2);
    
    return fig.canvas

a("L for f")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# <p style="padding-bottom:40%;"> </p>

# %% [markdown]
# #### Solution

# %% [markdown]
# That is, linearize $f$ around the point $(a,b) = (x(t_0),y(t_0))$.
#
# $$\frac{d}{dt} f(x(t),y(t)) = \frac{d}{dt} L(x(t),y(t))$$

# %% [markdown]
# $$= \frac{d}{dt} \left( f(a,b) + f_x(a,b)(x(t)-a) + f_y(a,b)(y(t) - b)\right)$$

# %% [markdown]
# $$= f_x(a,b) x'(t) + f_y(a,b) y'(t)$$

# %% [markdown]
# $$= \frac{\partial f}{\partial x}\frac{dx}{dt} + \frac{\partial f}{\partial y}\frac{dy}{dt}$$ where, again, we're careful to evaluate the partials at the appropriate point.

# %% [markdown]
# ### <p style="padding-bottom:40%;"> </p>

# %% [markdown]
# <div class="alert alert-block alert-info shadow">
#     <strong>The Chain Rule</strong>
#
# <p>If $f(x_1,\ldots,x_n)$ is differentiable at $\vec x_0 = \langle x_1(t_0),\ldots,x_n(t_0) \rangle$ and each $x_i$ is differentiable at $t_0$, then
#
# $$ \frac {df}{dt}\Big|_{t_0} = \sum_{i=1}^n \frac{\partial f}{\partial x_i}\Big|_{\vec x_0}\frac{dx_i}{dt}\Big|_{t_0} $$</p>
# </div>

# %% [markdown]
# <p style="padding-bottom:40%;"> </p>

# %% [markdown]
# ## Other forms
#
# Other cases can be handled by extrapolating from the case above.
#
#
#
# $$\frac{\partial}{\partial t} f(x(s,t),y(s,t),z(s,t)) = \frac{\partial f}{\partial x} \frac{\partial x}{\partial t} + \frac{\partial f}{\partial y}\frac{\partial y}{\partial t} +\frac{\partial f}{\partial z}\frac{\partial z}{\partial t} $$

# %% [markdown]
# <p style="padding-bottom:40%;"> </p>

# %% [markdown]
# <div class="alert alert-block alert-success shadow">
# <strong>Notation</strong>
#
# <p>We introduce the <strong>gradient</strong> vector of a function $$\nabla f = \begin{bmatrix} f_{x_1} \\ f_{x_2} \\ \vdots \\ f_{x_n} \end{bmatrix}$$
#
#
# <p>Thus for differentiable functions $f:\RR^n\to \RR$ and $\vec r: \RR \to \RR^n$, the composition has derivative
#
# $$\frac{d}{dt} f(\vec r(t)) = \nabla f(\vec r(t))\cdot \vec r'(t).$$</p>
#
# </div>

# %% [markdown]
# *There will be <b>much</b> more to say about this later; for now, just treat it as notation.*

# %% [markdown]
# <p style="padding-bottom:40%;"> </p>

# %% [markdown]
# ### Example
#
# A particle circles the $z$-axis every second at a distance of 1 unit. If it is confined to the surface $z=xy$, find the maximum of $\frac{dz}{dt}$.

# %%
# def a(TITLE):
#     if TITLE in plt.get_figlabels():
#         plt.close(plt.figure(TITLE))
    
#     plt.ioff()
#     fig = plt.figure(num=TITLE)
#     ax = fig.add_subplot(projection="3d")
#     plt.ion()
    
#     x = y = np.linspace(-1,1,100)
#     x,y = np.meshgrid(x,y)
#     ax.plot_surface(x,y,x*y,cmap='viridis',alpha=.3);
#     t = np.linspace(-pi,pi,100)
#     ax.plot(cos(t),sin(t),1/2*sin(2*t));
    
#     return fig.canvas

# a("Particle on a surface")

Video("../img/particle_spinning_on_surface.mp4", html_attributes="loop autoplay")
# Out:
# <video src="../img/particle_spinning_on_surface.mp4" loop autoplay  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# #### Solution

# %% [markdown]
# Note the period is 1 second, so $x = \cos(2\pi t), y = \sin (2\pi t)$.
#
# $$ \frac{dz}{dt} = \frac{\partial z}{\partial x}\frac{dx}{dt} + \frac{\partial z}{\partial y}\frac{dy}{dt} $$
#
# $$ = y (-2\pi\sin (2\pi t)) + x(2\pi \cos(2\pi t)) $$
#
# $$ = -2\pi\sin^2 (2\pi t) + 2\pi \cos^2(2\pi t) $$
#
# $$ = 2\pi \cos(4\pi t) $$ which has a maximum of $2\pi$.

# %% [markdown]
# ### <p style="padding-bottom:40%;"> </p>

# %% [markdown]
# ### Example
#
# The base radius of a right cone is increasing at a rate of  1 cm/min, and its height is decreasing at 2cm/min. When the base has radius 4 cm and the height is 8 cm, is the volume increasing or decreasing?

# %%
def a(TITLE):
    if TITLE in plt.get_figlabels():
        plt.close(plt.figure(TITLE))
    
    plt.ioff()
    fig = plt.figure(num=TITLE)
    plt.ion()
    ax = fig.add_subplot(projection='3d') 
    
    # make axes lines
    ax.plot([-1,1],[0,0],[0,0],'gray')
    ax.plot([0,0],[-1,1],[0,0],'gray')
    ax.plot([0,0],[0,0],[-1,1],'gray')   

    for c in 'xyz':
        # getattr(ax,f"set_{c}lim")([-1,1]);    
        getattr(ax,f"set_{c}label")(f"${c}$",size=16)
    ax.set_xlim((-5,5))
    ax.set_ylim((-5,5))
    ax.set_zlim((0,10))
        
    slider = widgets.FloatSlider(min=-.5, max = .5)

    dt = slider.value
    
    r = np.linspace(0,4+dt,75)
    t = np.linspace(0,2*np.pi,75)
    r,t = np.meshgrid(r,t)

    ax.plot_surface(r*cos(t),r*sin(t),-2*dt+8 - r*(-2*dt+8)/(dt+4),alpha=.5,color="#333552")

    pl = ax.plot([4+dt,0,0],[0,0,0],[0,0,8-dt*2],'k',lw=2)[0]
 

    def update(change):
        dt = slider.value
        
        ax.collections.pop()
    
        r = np.linspace(0,4+dt,75)
        t = np.linspace(0,2*np.pi,75)
        r,t = np.meshgrid(r,t)

        ax.plot_surface(r*cos(t),r*sin(t),-2*dt+8 - r*(-2*dt+8)/(dt+4),alpha=.5, color="#333552")

        pl.set_data_3d([4+dt,0,0],[0,0,0],[0,0,8-dt*2])
    
    slider.observe(update, names='value')
    
    return widgets.VBox([slider, fig.canvas])

a("Piled High")
# Out:
# VBox(children=(FloatSlider(value=0.0, max=0.5, min=-0.5), Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset or…

# %% [markdown]
# <p style="padding-bottom:40%;"> </p>

# %% [markdown]
# ## Example
#
# Suppose $f(x,y)$ has continuous derivatives of all order. Express $\frac{\partial^2 f}{\partial r\partial \theta}$ in terms of the partial derivatives of $f$.
#
# $r$ and $\theta$ are the usual polar coordinates.

# %% [markdown]
# #### Solution

# %% [markdown]
# $$\frac{\partial f}{\partial r} = f_x  \frac{\partial x}{\partial r} + f_y \frac{\partial y}{\partial r}$$
#
# $$ = f_x \cos \theta + f_y \sin \theta $$

# %% [markdown]
# \begin{align*}\frac{\partial^2 f}{\partial \theta \partial r } \\
# \ &= \left(f_{xx} \frac{\partial x}{\partial \theta} + f_{xy} \frac{\partial y}{\partial \theta}\right)\cos \theta - f_x \sin \theta + \left(f_{yx} \frac{\partial x}{\partial \theta} + f_{yy} \frac{\partial y}{\partial \theta}\right)\sin \theta + f_y \cos \theta \\
# \ &= (f_{yy} - f_{xx})r\sin\theta \cos \theta + f_{xy} r \cos (2\theta) + f_y \cos \theta - f_x \sin\theta
# \end{align*}

# %% [markdown]
# ###
# <p style="padding-bottom:40%;"> </p>

# %% [markdown]
# ### Exercises
#
#   1. Wheat production $W$ in a given year depends on the average temperature $T$ and the annual rainfall $R$. Scientists estimate that the average temperature is rising at a rate of $0.15^\circ$C/year and rainfall is decreasing at a rate of $0.1$ cm/year. They also estimate that at current production levels, $\partial W/\partial T = -2$ and $\partial W/\partial R = 8$.
#
#   - What is the significance of the signs of these partial derivatives?
#
#   - Estimate the current rate of change of wheat production, $dW/dt$.

# %% [markdown]
# <p style="padding-bottom:40%;"> </p>

# %% [markdown]
#   2. Suppose
# \begin{align}
# z &= z(x,y) \\
# x &= x(u,v) \\
# y &= y(u,v) \\
# u &= u(s,t) \\
# v &= v(s,t) \\
# \end{align}
# are all differentiable. Find an expression for $\frac{\partial z}{\partial s}$.

# %% [markdown]
# #### Solution

# %% [markdown]
# $$ \frac{\partial z}{\partial s} = \frac{\partial z}{\partial x}\frac{\partial x}{\partial u}\frac{\partial u}{\partial s}
# + \frac{\partial z}{\partial x}\frac{\partial x}{\partial v}\frac{\partial v}{\partial s}
# + \frac{\partial z}{\partial y}\frac{\partial y}{\partial u}\frac{\partial u}{\partial s}
# + \frac{\partial z}{\partial y}\frac{\partial y}{\partial v}\frac{\partial v}{\partial s} $$

# %% [markdown]
# ###
# <p style="padding-bottom:40%;"> </p>

# %% [markdown]
# ## Example
#
# If $g:\RR\to\RR$ is any smooth function, show that $f(x,y) = g(x^2+y^2)$ is radially symmetric. That is, $\frac{\partial f}{\partial \theta} =0$

# %% [markdown]
# #### Solution

# %% [markdown]
# $$\frac{\partial f }{\partial \theta} = \frac{\partial}{\partial x} (g(x^2 + y^2)) \frac{\partial x}{\partial \theta}
# + \frac{\partial}{\partial y} (g(x^2 + y^2)) \frac{\partial y}{\partial \theta} $$
#
# $$ = g'(x^2 + y^2)2x (-r \sin \theta) + g'(x^2 + y^2)2y (-r \cos \theta) $$
#
# $$ = g'(x^2 + y^2)( -2xy + 2yx) = 0 $$

# %% [markdown]
# ###
# <p style="padding-bottom:40%;"> </p>

# %% [markdown]
# ## Implicit differentiation
#
# Every implicit relationship among variables $x$ and $y$ can be expressed as a level set $$ F(x,y) = c. $$

# %% [markdown]
# #### Solution

# %% [markdown]
# To find the rate of change $\frac{dy}{dx}$ determined by this relation, we can be clever and differentiate the whole expression with respect to $x$.

# %% [markdown]
# $$ \frac{d}{dx}F(x,y) = 0$$

# %% [markdown]
# **WARNING** Mind your $d$'s and $\partial$'s.

# %% [markdown]
# $$ \frac{d}{dx}F(x,y(x)) = 0$$

# %% [markdown]
# $$ \frac{\partial F}{\partial x}\frac{dx}{dx} + \frac{\partial F}{\partial y}\frac{dy}{dx} = 0$$

# %% [markdown]
# $$ \frac{dy}{dx} = -\frac{F_x}{F_y}$$

# %% [markdown]
# ###
# <p style="padding-bottom:40%;"> </p>

# %% [markdown]
# <div class="alert alert-block alert-success shadow">
# <strong>Remark</strong>
#
# <p> This formula is actual the key to a hugely important theorem in mathematics called the Implicit Function theorem which says that if $F_{x_j} \neq 0 $ at some point $P\in \RR^n$, the relationship $$F(x_1, \ldots, x_n) = k = F(P)$$ defines $x_j$ implicitly as a function of the other $x_i$'s and
#     $$ \frac{\partial x_j}{\partial x_i} = -\frac{F_{x_i} (P)}{F_{x_j} (P)}$$
# </div>

# %% [markdown]
# ###
# <p style="padding-bottom:40%;"> </p>

# %% [markdown]
# ## Example
#
# Find the slope of the tangent line to
#
# $$ x \sin(y) - \frac12 = \sqrt{2} - 2\cos(xy)$$ at the point $\left(\frac12,\frac\pi2\right)$.

# %%
def a(TITLE):
    if TITLE in plt.get_figlabels():
        plt.close(plt.figure(TITLE))
    
    plt.ioff()
    fig, ax = plt.subplots(num=TITLE)
    plt.ion()
    
    x = y = np.linspace(-pi,pi,102)
    x,y = np.meshgrid(x,y)
    z = x*sin(y) + 2*cos(x*y) - sqrt(2) - 1/2

    cp = ax.contour(x,y,z,levels=arange(-3,3.4,.5),alpha=.5,colors='y')

    cp = ax.contour(x,y,z,levels=[0],colors='y')
    # plt.clabel(cp,fmt="%d");
    x = np.linspace(-2.5,3.5,102)
    ax.plot(x,pi/2 + (x-1/2) * (sqrt(2) - pi),color='r',lw=3);
    ax.grid(True)
    ax.scatter(1/2,pi/2)
    ax.set_xlim(-pi,pi)
    ax.set_ylim(-pi,pi);
    
    return fig.canvas

a("Implicit example")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# <p style="padding-bottom:40%;"> </p>

# %% [markdown]
# #### Solution

# %% [markdown]
# $$F(x,y) = x \sin y + 2\cos(xy) = \frac12 + \sqrt 2 $$

# %% [markdown]
# $$ \frac{dy}{dx} = \left.-\frac{F_x}{F_y} \right\rvert_{(1/2,\pi/2)} = \left.-\frac{\sin y -2\sin(xy)y}{x\cos y -2 \sin(xy)x}\right\rvert_{(1/2,\pi/2)} $$

# %% [markdown]
# $$ = - \frac{1 - \frac{\pi}{\sqrt2}}{-\frac{1}{\sqrt2}} = \sqrt2 - \pi $$

# %% [markdown]
# ###<p style="padding-bottom:40%;"> </p>
